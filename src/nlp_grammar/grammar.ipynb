# %%
import language_tool_python
import json

tool = language_tool_python.LanguageTool('en-US')

# %%
def check_text_with_language_tool(text: str) -> dict:
    # Initialize the language tool for English

    # Analyze the text
    matches = tool.check(text)

    # Create a list for corrections
    corrections = []

    # Process each match to extract the necessary details
    for match in matches:
        corrections.append({
            "character_offset": match.offset,
            "character_endset": match.offset + match.errorLength,
            "original_text": text[match.offset:match.offset + match.errorLength],
            "message": match.message,
            "category": match.category,
            "rule_id": match.ruleId,
            "replacements": match.replacements
        })

    # Generate revised text with corrections applied
    revised_text = language_tool_python.utils.correct(text, matches)

    # Construct the final result
    result = {
        "original_text": text,
        "revised_text": revised_text,
        "corrections": corrections
    }

    return result

# Example Usage
input_text = "Weeed,, teacher is, teachhing. Mr. Smith is here . They is a great teacher . Mrs. Johnson and they loves to bake ."
output = check_text_with_language_tool(input_text)
print(output)
print(json.dumps(output, indent=4))
# Out:
# {'original_text': 'Weeed,, teacher is, teachhing. Mr. Smith is here . They is a great teacher . Mrs. Johnson and they loves to bake .', 'revised_text': 'Weed, teacher is, teaching. Mr. Smith is here. They are a great teacher. Mrs. Johnson and they love to bake.', 'corrections': [{'character_offset': 0, 'character_endset': 5, 'original_text': 'Weeed', 'message': 'Possible spelling mistake found.', 'category': 'TYPOS', 'rule_id': 'MORFOLOGIK_RULE_EN_US', 'replacements': ['Weed', 'Weeded', 'WEEE', 'Weened']}, {'character_offset': 5, 'character_endset': 7, 'original_text': ',,', 'message': 'Two consecutive commas', 'category': 'PUNCTUATION', 'rule_id': 'DOUBLE_PUNCTUATION', 'replacements': [',']}, {'character_offset': 20, 'character_endset': 29, 'original_text': 'teachhing', 'message': 'Possible spelling mistake found.', 'category': 'TYPOS', 'rule_id': 'MORFOLOGIK_RULE_EN_US', 'replacements': ['teaching', 'teach hing']}, {'character_offset': 48, 'character_endset': 50, 'original_text': ' .', 'message': 'Don’t put a space before the full stop.', 'category': 'TYPOGRAPHY', 'rule_id': 'COMMA_PARENTHESIS_WHITESPACE', 'replacements': ['.']}, {'character_offset': 56, 'character_endset': 58, 'original_text': 'is', 'message': 'Use a third-person plural verb with ‘they’.', 'category': 'GRAMMAR', 'rule_id': 'PERS_PRONOUN_AGREEMENT', 'replacements': ['are', 'were']}, {'character_offset': 74, 'character_endset': 76, 'original_text': ' .', 'message': 'Don’t put a space before the full stop.', 'category': 'TYPOGRAPHY', 'rule_id': 'COMMA_PARENTHESIS_WHITESPACE', 'replacements': ['.']}, {'character_offset': 99, 'character_endset': 104, 'original_text': 'loves', 'message': 'The pronoun ‘they’ must be used with a non-third-person form of a verb.', 'category': 'GRAMMAR', 'rule_id': 'NON3PRS_VERB', 'replacements': ['love']}, {'character_offset': 112, 'character_endset': 114, 'original_text': ' .', 'message': 'Don’t put a space before the full stop.', 'category': 'TYPOGRAPHY', 'rule_id': 'COMMA_PARENTHESIS_WHITESPACE', 'replacements': ['.']}]}
# {
#     "original_text": "Weeed,, teacher is, teachhing. Mr. Smith is here . They is a great teacher . Mrs. Johnson and they loves to bake .",
#     "revised_text": "Weed, teacher is, teaching. Mr. Smith is here. They are a great teacher. Mrs. Johnson and they love to bake.",
#     "corrections": [
#         {
#             "character_offset": 0,
#             "character_endset": 5,
#             "original_text": "Weeed",
#             "message": "Possible spelling mistake found.",
#             "category": "TYPOS",
#             "rule_id": "MORFOLOGIK_RULE_EN_US",
#             "replacements": [
#                 "Weed",
#                 "Weeded",
#                 "WEEE",
#                 "Weened"
#             ]
#         },
#         {
#             "character_offset": 5,
#             "character_endset": 7,
#             "original_text": ",,",
#             "message": "Two consecutive commas",
#             "category": "PUNCTUATION",
#             "rule_id": "DOUBLE_PUNCTUATION",
#             "replacements": [
#                 ","
#             ]
#         },
#         {
#             "character_offset": 20,
#             "character_endset": 29,
#             "original_text": "teachhing",
#             "message": "Possible spelling mistake found.",
#             "category": "TYPOS",
#             "rule_id": "MORFOLOGIK_RULE_EN_US",
#             "replacements": [
#                 "teaching",
#                 "teach hing"
#             ]
#         },
#         {
#             "character_offset": 48,
#             "character_endset": 50,
#             "original_text": " .",
#             "message": "Don\u2019t put a space before the full stop.",
#             "category": "TYPOGRAPHY",
#             "rule_id": "COMMA_PARENTHESIS_WHITESPACE",
#             "replacements": [
#                 "."
#             ]
#         },
#         {
#             "character_offset": 56,
#             "character_endset": 58,
#             "original_text": "is",
#             "message": "Use a third-person plural verb with \u2018they\u2019.",
#             "category": "GRAMMAR",
#             "rule_id": "PERS_PRONOUN_AGREEMENT",
#             "replacements": [
#                 "are",
#                 "were"
#             ]
#         },
#         {
#             "character_offset": 74,
#             "character_endset": 76,
#             "original_text": " .",
#             "message": "Don\u2019t put a space before the full stop.",
#             "category": "TYPOGRAPHY",
#             "rule_id": "COMMA_PARENTHESIS_WHITESPACE",
#             "replacements": [
#                 "."
#             ]
#         },
#         {
#             "character_offset": 99,
#             "character_endset": 104,
#             "original_text": "loves",
#             "message": "The pronoun \u2018they\u2019 must be used with a non-third-person form of a verb.",
#             "category": "GRAMMAR",
#             "rule_id": "NON3PRS_VERB",
#             "replacements": [
#                 "love"
#             ]
#         },
#         {
#             "character_offset": 112,
#             "character_endset": 114,
#             "original_text": " .",
#             "message": "Don\u2019t put a space before the full stop.",
#             "category": "TYPOGRAPHY",
#             "rule_id": "COMMA_PARENTHESIS_WHITESPACE",
#             "replacements": [
#                 "."
#             ]
#         }
#     ]
# }
